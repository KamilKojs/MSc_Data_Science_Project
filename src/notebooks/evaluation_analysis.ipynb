# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
column_names = ['second', 'function_id', 'total_inference_time', 'model_to_gpu_time', 'inference_time', 'unload_from_gpu_time']
baseline = pd.read_csv('../../results/baseline2/evaluation_results.txt', header=None, names=column_names)
column_names = ['second', 'function_id', 'total_inference_time', 'preloaded_function_id_model', 'model_on_gpu_before_preloading', 'manager_time_series_time', 'model_to_gpu_time', 'inference_time', 'unload_from_gpu_time']
experiment_3 = pd.read_csv('../../results/experiment3/evaluation_results.txt', header=None, names=column_names)
column_names = ['second', 'function_id', 'total_inference_time', 'preloaded_function_id_model_1', 'preloaded_function_id_model_2', 'preloaded_function_id_model_3', 'preloaded_function_id_model_4', 'model_on_gpu_before_preloading_1', 'model_on_gpu_before_preloading_2', 'model_on_gpu_before_preloading_3', 'model_on_gpu_before_preloading_4', 'manager_time_series_time', 'model_to_gpu_time', 'inference_time', 'unload_from_gpu_time']
experiment_4 = pd.read_csv('../../results/experiment4/evaluation_results.txt', header=None, names=column_names)

# %%
baseline['total_inference_time_including_queue'] = 0.0
prev_second = None
cumulative_time = 0.0

for index, row in baseline.iterrows():
    # If the second id changes, reset cumulative time
    if prev_second != row['second']:
        cumulative_time = 0.0
        prev_second = row['second']
    
    # Update cumulative time with the current row's inference time
    cumulative_time += row['total_inference_time']
    
    # Update the new column with the cumulative time
    baseline.at[index, 'total_inference_time_including_queue'] = cumulative_time

experiment_3['total_inference_time_including_queue'] = 0.0
prev_second = None
cumulative_time = 0.0

for index, row in experiment_3.iterrows():
    # If the second id changes, reset cumulative time
    if prev_second != row['second']:
        cumulative_time = 0.0
        prev_second = row['second']
    
    # Update cumulative time with the current row's inference time
    cumulative_time += row['total_inference_time']
    
    # Update the new column with the cumulative time
    experiment_3.at[index, 'total_inference_time_including_queue'] = cumulative_time

experiment_4['total_inference_time_including_queue'] = 0.0
prev_second = None
cumulative_time = 0.0

for index, row in experiment_4.iterrows():
    # If the second id changes, reset cumulative time
    if prev_second != row['second']:
        cumulative_time = 0.0
        prev_second = row['second']
    
    # Update cumulative time with the current row's inference time
    cumulative_time += row['total_inference_time']
    
    # Update the new column with the cumulative time
    experiment_4.at[index, 'total_inference_time_including_queue'] = cumulative_time

# %%
baseline
# Out:
#         second  function_id  total_inference_time  model_to_gpu_time  \
# 0       950400            1              1.496509           0.061659
# 1       950400           56              0.174300           0.045233
# 2       950400           69              0.173842           0.045104
# 3       950400           71              0.174551           0.044923
# 4       950401            1              0.118109           0.045499
# ...        ...          ...                   ...                ...
# 23731  1209302           50              0.117529           0.046534
# 23732  1209363           55              0.119810           0.046925
# 23733  1209424           31              0.120002           0.046952
# 23734  1209432           37              0.120375           0.046852
# 23735  1209484           55              0.117763           0.046853
#
#        inference_time  unload_from_gpu_time  \
# 0            0.266298              0.109542
# 1            0.014603              0.105168
# ...

# %%
experiment_3
# Out:
#         second  function_id  total_inference_time  \
# 0       950400            1              0.269675
# 1       950400           56              0.161484
# 2       950400           69              0.175446
# 3       950400           71              0.176522
# 4       950401            1              0.024399
# ...        ...          ...                   ...
# 23731  1209302           50              0.122801
# 23732  1209363           55              0.025337
# 23733  1209424           31              0.123516
# 23734  1209432           37              0.122922
# 23735  1209484           55              0.025196
#
#        preloaded_function_id_model  model_on_gpu_before_preloading  \
# 0                                1                               1
# 1                                1                               1
# 2                                1                               1
# 3                                1                               1
# ...

# %%
experiment_4
# Out:
#         second  function_id  total_inference_time  \
# 0       950400            1              0.254746
# 1       950400           56              0.024020
# 2       950400           69              0.023223
# 3       950400           71              0.156590
# 4       950401            1              0.023796
# ...        ...          ...                   ...
# 23728  1209302           50              0.024760
# 23729  1209363           55              0.024714
# 23730  1209424           31              0.121995
# 23731  1209432           37              0.024818
# 23732  1209484           55              0.024961
#
#        preloaded_function_id_model_1  preloaded_function_id_model_2  \
# 0                                 55                             56
# 1                                 55                             56
# 2                                 55                             56
# 3                                 56                             69
# ...

# %%
baseline.function_id.unique()
# Out:
# array([ 1, 56, 69, 71, 50, 31, 55, 37, 21,  7])

# %%
filtered_1 = baseline[baseline['function_id'] == 1]
filtered_56 = baseline[baseline['function_id'] == 56]
filtered_69 = baseline[baseline['function_id'] == 69]
filtered_71 = baseline[baseline['function_id'] == 71]
filtered_50 = baseline[baseline['function_id'] == 50]
filtered_31 = baseline[baseline['function_id'] == 31]
filtered_55 = baseline[baseline['function_id'] == 55]
filtered_37 = baseline[baseline['function_id'] == 37]
filtered_21 = baseline[baseline['function_id'] == 21]
filtered_7 = baseline[baseline['function_id'] == 7]

# %%
ex3_filtered_1 = experiment_3[experiment_3['function_id'] == 1]
ex3_filtered_56 = experiment_3[experiment_3['function_id'] == 56]
ex3_filtered_69 = experiment_3[experiment_3['function_id'] == 69]
ex3_filtered_71 = experiment_3[experiment_3['function_id'] == 71]
ex3_filtered_50 = experiment_3[experiment_3['function_id'] == 50]
ex3_filtered_31 = experiment_3[experiment_3['function_id'] == 31]
ex3_filtered_55 = experiment_3[experiment_3['function_id'] == 55]
ex3_filtered_37 = experiment_3[experiment_3['function_id'] == 37]
ex3_filtered_21 = experiment_3[experiment_3['function_id'] == 21]
ex3_filtered_7 = experiment_3[experiment_3['function_id'] == 7]

# %%
ex4_filtered_1 = experiment_4[experiment_4['function_id'] == 1]
ex4_filtered_56 = experiment_4[experiment_4['function_id'] == 56]
ex4_filtered_69 = experiment_4[experiment_4['function_id'] == 69]
ex4_filtered_71 = experiment_4[experiment_4['function_id'] == 71]
ex4_filtered_50 = experiment_4[experiment_4['function_id'] == 50]
ex4_filtered_31 = experiment_4[experiment_4['function_id'] == 31]
ex4_filtered_55 = experiment_4[experiment_4['function_id'] == 55]
ex4_filtered_37 = experiment_4[experiment_4['function_id'] == 37]
ex4_filtered_21 = experiment_4[experiment_4['function_id'] == 21]
ex4_filtered_7 = experiment_4[experiment_4['function_id'] == 7]

# %% [markdown]
# # general statistics

# %%
print(f"Average total single inference time: {filtered_1['total_inference_time'].mean()}")
print(f"Average model_to_gpu_time: {filtered_1['model_to_gpu_time'].mean()}")
print(f"Average inference_time: {filtered_1['inference_time'].mean()}")
print(f"Average unload_from_gpu_time: {filtered_1['unload_from_gpu_time'].mean()}")

print(f"Average manager_time_series_time: {ex3_filtered_1['manager_time_series_time'].mean()}")

print(f"Average inference time for baseline 1: {filtered_1['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 7: {filtered_7['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 21: {filtered_21['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 31: {filtered_31['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 37: {filtered_37['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 50: {filtered_50['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 55: {filtered_55['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 56: {filtered_56['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 69: {filtered_69['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for baseline 71: {filtered_71['total_inference_time_including_queue'].mean()}")

print(f"Average inference time for experiment 3 function id 1: {ex3_filtered_1['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 7: {ex3_filtered_7['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 21: {ex3_filtered_21['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 31: {ex3_filtered_31['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 37: {ex3_filtered_37['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 50: {ex3_filtered_50['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 55: {ex3_filtered_55['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 56: {ex3_filtered_56['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 69: {ex3_filtered_69['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 3 function id 71: {ex3_filtered_71['total_inference_time_including_queue'].mean()}")

print(f"Average inference time for experiment 4 function id 1: {ex4_filtered_1['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 7: {ex4_filtered_7['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 21: {ex4_filtered_21['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 31: {ex4_filtered_31['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 37: {ex4_filtered_37['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 50: {ex4_filtered_50['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 55: {ex4_filtered_55['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 56: {ex4_filtered_56['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 69: {ex4_filtered_69['total_inference_time_including_queue'].mean()}")
print(f"Average inference time for experiment 4 function id 71: {ex4_filtered_71['total_inference_time_including_queue'].mean()}")
# Out:
# Average total single inference time: 0.11453889758947275
# Average model_to_gpu_time: 0.04475240510422136
# Average inference_time: 0.01445399004413793
# Average unload_from_gpu_time: 0.04629456776845736
# Average manager_time_series_time: 0.2437249837595417
# Average inference time for baseline 1: 0.11453889758947275
# Average inference time for baseline 7: 0.1467152594745304
# Average inference time for baseline 21: 0.1559772393698029
# Average inference time for baseline 31: 0.16083562473318277
# Average inference time for baseline 37: 0.16491793727610576
# Average inference time for baseline 50: 0.16691979407160365
# Average inference time for baseline 55: 0.1645731031205134
# Average inference time for baseline 56: 0.16424493795191794
# Average inference time for baseline 69: 0.17918837896668077
# Average inference time for baseline 71: 0.18574153052435974
# Average inference time for experiment 3 function id 1: 0.048097991873633554
# ...

# %% [markdown]
# Below is missed improvement code to get how many times a correct model was chosen for preloading but this iprovement was not taken into accouint because of specifics of the experiment that all requests for one second were performend sequentially.

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 3000], row=1, col=1)
fig.update_yaxes(range=[0, 3000], row=2, col=1)
fig.update_yaxes(range=[0, 3000], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_1['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_1['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_1['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 1 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 2500], row=1, col=1)
fig.update_yaxes(range=[0, 2500], row=2, col=1)
fig.update_yaxes(range=[0, 2500], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_7['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_7['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_7['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 7 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 150], row=1, col=1)
fig.update_yaxes(range=[0, 150], row=2, col=1)
fig.update_yaxes(range=[0, 150], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_21['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_21['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_21['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 21 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 300], row=1, col=1)
fig.update_yaxes(range=[0, 300], row=2, col=1)
fig.update_yaxes(range=[0, 300], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_31['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_31['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_31['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 31 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 400], row=1, col=1)
fig.update_yaxes(range=[0, 400], row=2, col=1)
fig.update_yaxes(range=[0, 400], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_37['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_37['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_37['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 37 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 200], row=1, col=1)
fig.update_yaxes(range=[0, 200], row=2, col=1)
fig.update_yaxes(range=[0, 200], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_50['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_50['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_50['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 50 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 400], row=1, col=1)
fig.update_yaxes(range=[0, 400], row=2, col=1)
fig.update_yaxes(range=[0, 400], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_55['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_55['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_55['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 55 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 250], row=1, col=1)
fig.update_yaxes(range=[0, 250], row=2, col=1)
fig.update_yaxes(range=[0, 250], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_56['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_56['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_56['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 56 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 150], row=1, col=1)
fig.update_yaxes(range=[0, 150], row=2, col=1)
fig.update_yaxes(range=[0, 150], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_69['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_69['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_69['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 69 (s)", showlegend=False, width=700, height=800)

fig.show()

# %%
fig = make_subplots(rows=3, cols=1, subplot_titles=("Baseline", "Experiment 2", "Experiment 3"))

fig.update_xaxes(range=[0, 0.5], row=1, col=1)
fig.update_xaxes(range=[0, 0.5], row=2, col=1)
fig.update_xaxes(range=[0, 0.5], row=3, col=1)

fig.update_yaxes(range=[0, 100], row=1, col=1)
fig.update_yaxes(range=[0, 100], row=2, col=1)
fig.update_yaxes(range=[0, 100], row=3, col=1)

histogram_baseline = go.Histogram(x=filtered_71['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_baseline, row=1, col=1)

histogram_preloading_1 = go.Histogram(x=ex3_filtered_71['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_1, row=2, col=1)

histogram_preloading_2 = go.Histogram(x=ex4_filtered_71['total_inference_time_including_queue'], nbinsx=1000, histnorm='')
fig.add_trace(histogram_preloading_2, row=3, col=1)

fig.update_layout(title_text="Histogram of Inference Time for Function ID 71 (s)", showlegend=False, width=700, height=800)

fig.show()
